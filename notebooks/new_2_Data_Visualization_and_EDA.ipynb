# %% [markdown]
# ## Dependencies
# Libraries needed in this notebook for data visualization and EDA

# %%
import sys
import pandas as pd
import numpy as np

import missingno as msno

import plotly.express as px

sys.path.append('..')
from starbucks_campaigns_analytics import read_complete_starbucks_data
from starbucks_campaigns_analytics.plotting import funnel_plot

# %% [markdown]
# ## Gather data

# %%
# Read Starbucks data using the helper function 
# defined in starbucks_campaigns_analytics module
df = read_complete_starbucks_data()
df.head()
# Out:
#                              person            event  time  \
# 0  78afa995795e4d85b5d9ceeca43f5fef   offer received     0
# 1  78afa995795e4d85b5d9ceeca43f5fef     offer viewed     6
# 2  78afa995795e4d85b5d9ceeca43f5fef      transaction   132
# 3  78afa995795e4d85b5d9ceeca43f5fef  offer completed   132
# 4  78afa995795e4d85b5d9ceeca43f5fef      transaction   144
#
#                            offer_id  amount  reward_expected gender  age  \
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN              NaN      F   75
# 1  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN              NaN      F   75
# 2                               NaN   19.89              NaN      F   75
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN              5.0      F   75
# 4                               NaN   17.78              NaN      F   75
#
#    became_member_on    income  profile_group  reward  difficulty  duration  \
# 0          20170509  100000.0              0     5.0         5.0     168.0
# 1          20170509  100000.0              0     5.0         5.0     168.0
# 2          20170509  100000.0              0     NaN         NaN       NaN
# 3          20170509  100000.0              0     5.0         5.0     168.0
# 4          20170509  100000.0              0     NaN         NaN       NaN
#
#   offer_type  web  email  mobile  social
# 0       bogo  1.0    1.0     1.0     0.0
# 1       bogo  1.0    1.0     1.0     0.0
# 2        NaN  NaN    NaN     NaN     NaN
# 3       bogo  1.0    1.0     1.0     0.0
# 4        NaN  NaN    NaN     NaN     NaN

# %%
# New columns for offer viewed (by type)
df['bogo_offer_viewed'] = ((df['event']=='offer viewed') 
                           & (df['offer_type']=='bogo'))

df['disc_offer_viewed'] = ((df['event']=='offer viewed') 
                           & (df['offer_type']=='discount'))

df['info_offer_viewed'] = ((df['event']=='offer viewed') 
                           & (df['offer_type']=='informational'))

df['#bogo_offer_viewed'] = df.groupby('person')['bogo_offer_viewed'].transform('sum')
df['#disc_offer_viewed'] = df.groupby('person')['disc_offer_viewed'].transform('sum')
df['#info_offer_viewed'] = df.groupby('person')['info_offer_viewed'].transform('sum')

# %%
# New columns for offer completed (by type)
df['bogo_offer_completed'] = ((df['event']=='offer completed') 
                           & (df['offer_type']=='bogo'))
df['disc_offer_completed'] = ((df['event']=='offer completed') 
                           & (df['offer_type']=='discount'))
# df['info_offer_completed'] = ((df['event']=='offer completed') 
#                            & (df['offer_type']=='informational'))

df['#bogo_offer_completed'] = df.groupby('person')['bogo_offer_completed'].transform('sum')
df['#disc_offer_completed'] = df.groupby('person')['disc_offer_completed'].transform('sum')
# df['#info_offer_completed'] = df.groupby('person')['info_offer_completed'].transform('sum')

# %%
# New columns for ratios (completed/viewed)
df['bogo_offer_ratio'] = df['#bogo_offer_completed']/df['#bogo_offer_viewed']
df['disc_offer_ratio'] = df['#disc_offer_completed']/df['#disc_offer_viewed']

# %%
df.sample(12)
# Out:
#                                   person            event  time  \
# 19577   2449f2f011d24c849f72b15303f89f4b   offer received   408
# 19753   79a1b2e7bab8420c98a59530a783155d      transaction   522
# 100695  ec539cd856754923995755f0dd1af470  offer completed   582
# 19241   fe0d05246e9040578a27cb39e23a1bdd  offer completed   240
# 193117  c0bdfd5f10d84c1e981c48c48373e983  offer completed   612
# 204315  ee8155c31f314673b8043c3881976c4b  offer completed   414
# 227757  81f948e3a4134729ba5c0e15d221ce5d      transaction   180
# 162154  d3956fdde71b4aa08a7d081f282a914f   offer received     0
# 113809  f64f9645524f493d83956f3211bb4c2d   offer received   168
# 187716  7d14c8ecf4ed4f0e8b817a8614bfaaa4   offer received     0
# 242349  5f4e00dd55a64825b3e377336fbf71db      transaction   384
# 121949  a0cc63f326024671a3abb2518f1f34c4   offer received   576
#
#                                 offer_id  amount  reward_expected gender  age  \
# 19577   ae264e3637204a6fb9bb56bc8210ddfd     NaN              NaN      F   37
# 19753                                NaN    7.76              NaN      F   46
# 100695  2906b810c7d4411798c6938adc9daaa5     NaN              2.0      F   78
# 19241   2906b810c7d4411798c6938adc9daaa5     NaN              2.0      M   91
# 193117  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN              3.0      M   84
# 204315  f19421c1d4aa40978ebb69ca19b0e20d     NaN              5.0      F   57
# 227757                               NaN   23.01              NaN      F   58
# 162154  fafdcd668e3743c1bb461111dcafc2a4     NaN              NaN      M   41
# 113809  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN              NaN      M   33
# 187716  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN              NaN      F   77
# 242349                               NaN   19.76              NaN      M   73
# 121949  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN              NaN      F   71
#
#         became_member_on   income  ...  info_offer_viewed  #bogo_offer_viewed  \
# 19577           20160131  51000.0  ...              False                 3.0
# 19753           20130927  42000.0  ...              False                 3.0
# 100695          20161107  44000.0  ...              False                 2.0
# 19241           20150208  78000.0  ...              False                 0.0
# 193117          20150808  43000.0  ...              False                 1.0
# 204315          20170824  95000.0  ...              False                 1.0
# 227757          20170731  61000.0  ...              False                 0.0
# 162154          20180517  85000.0  ...              False                 0.0
# 113809          20171103  58000.0  ...              False                 3.0
# 187716          20170106  37000.0  ...              False                 0.0
# 242349          20180530  61000.0  ...              False                 1.0
# 121949          20180722  63000.0  ...              False                 1.0
#
#         #disc_offer_viewed  #info_offer_viewed bogo_offer_completed  \
# 19577                  0.0                 0.0                False
# 19753                  0.0                 0.0                False
# 100695                 0.0                 0.0                False
# 19241                  3.0                 3.0                False
# 193117                 2.0                 1.0                False
# 204315                 1.0                 0.0                 True
# 227757                 2.0                 1.0                False
# 162154                 1.0                 2.0                False
# 113809                 1.0                 0.0                False
# 187716                 2.0                 1.0                False
# 242349                 2.0                 1.0                False
# 121949                 0.0                 1.0                False
#
#         disc_offer_completed  #bogo_offer_completed  #disc_offer_completed  \
# 19577                  False                    2.0                    0.0
# 19753                  False                    1.0                    1.0
# 100695                  True                    2.0                    1.0
# 19241                   True                    0.0                    3.0
# 193117                  True                    0.0                    2.0
# 204315                 False                    2.0                    3.0
# 227757                 False                    0.0                    2.0
# 162154                 False                    1.0                    1.0
# 113809                 False                    0.0                    0.0
# 187716                 False                    0.0                    2.0
# 242349                 False                    0.0                    2.0
# 121949                 False                    0.0                    0.0
#
#         bogo_offer_ratio  disc_offer_ratio
# 19577           0.666667               NaN
# 19753           0.333333               inf
# 100695          1.000000               inf
# 19241                NaN               1.0
# 193117          0.000000               1.0
# 204315          2.000000               3.0
# 227757               NaN               1.0
# 162154               inf               1.0
# 113809          0.000000               0.0
# 187716               NaN               1.0
# 242349          0.000000               1.0
# 121949          0.000000               NaN
#
# [12 rows x 31 columns]

# %%
df.loc[(df['person']=='ee8155c31f314673b8043c3881976c4b') & (df['event']=='offer completed')]
# Out:
#                                   person            event  time  \
# 204306  ee8155c31f314673b8043c3881976c4b  offer completed    60
# 204309  ee8155c31f314673b8043c3881976c4b  offer completed   210
# 204315  ee8155c31f314673b8043c3881976c4b  offer completed   414
# 204316  ee8155c31f314673b8043c3881976c4b  offer completed   414
# 204325  ee8155c31f314673b8043c3881976c4b  offer completed   594
#
#                                 offer_id  amount  reward_expected gender  age  \
# 204306  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN              5.0      F   57
# 204309  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN              5.0      F   57
# 204315  f19421c1d4aa40978ebb69ca19b0e20d     NaN              5.0      F   57
# 204316  fafdcd668e3743c1bb461111dcafc2a4     NaN              2.0      F   57
# 204325  ae264e3637204a6fb9bb56bc8210ddfd     NaN             10.0      F   57
#
#         became_member_on   income  ...  info_offer_viewed  #bogo_offer_viewed  \
# 204306          20170824  95000.0  ...              False                 1.0
# 204309          20170824  95000.0  ...              False                 1.0
# 204315          20170824  95000.0  ...              False                 1.0
# 204316          20170824  95000.0  ...              False                 1.0
# 204325          20170824  95000.0  ...              False                 1.0
#
#         #disc_offer_viewed  #info_offer_viewed bogo_offer_completed  \
# 204306                 1.0                 0.0                False
# 204309                 1.0                 0.0                False
# 204315                 1.0                 0.0                 True
# 204316                 1.0                 0.0                False
# 204325                 1.0                 0.0                 True
#
#         disc_offer_completed  #bogo_offer_completed  #disc_offer_completed  \
# 204306                  True                    2.0                    3.0
# 204309                  True                    2.0                    3.0
# 204315                 False                    2.0                    3.0
# 204316                  True                    2.0                    3.0
# 204325                 False                    2.0                    3.0
#
#         bogo_offer_ratio  disc_offer_ratio
# 204306               2.0               3.0
# 204309               2.0               3.0
# 204315               2.0               3.0
# 204316               2.0               3.0
# 204325               2.0               3.0
#
# [5 rows x 31 columns]

# %%
df.sample(15)

# %%
# dataframe only with person who view at least one bogo offer
person_bogo = df.loc[((df['event']=='offer viewed') 
                      & (df['offer_type']=='bogo')),'person']
df_bogo = df[df['person'].isin(person_bogo)].copy()

# %%
df_bogo.shape

# %%
df_bogo['bogo_offer_viewed'] = ((df_bogo['event']=='offer viewed') 
                                & (df_bogo['offer_type']=='bogo'))
df_bogo['bogo_offer_viewed'] = ((df_bogo['event']=='offer viewed') 
                                & (df_bogo['offer_type']=='bogo'))

# %%
df_bogo.sample(15)
